# %%
from IPython.display import HTML

HTML("""
<style>

    /* 1. Tamaño y espacio de los ítems de lista (li) */
    .reveal ul li, .reveal ol li {
        font-size: 32px !important;    /* Ajusta este valor */
        margin-bottom: 15px !important; /* Espacio entre puntos */
        line-height: 1.3 !important;    /* Espacio entre líneas del mismo punto */
    }

    /* 2. Estilo de las sub-listas (listas dentro de listas) */
    .reveal li > ul li, .reveal li > ol li {
        font-size: 0.85em !important;   /* Un poco más pequeñas que las principales */
        list-style-type: circle !important; 
    }

    /* 3. Cambiar el color de las viñetas (bullets) */
    .reveal ul li::marker {
        color: #3498db !important;      /* Un azul sutil, cámbialo a tu gusto */
        font-weight: bold;
    }

    /* 4. Ajustar el ancho del contenedor para que las listas no se corten */
    .reveal .slides {
        text-align: left !important;    /* Alinea el texto a la izquierda si prefieres */
    }
    /* 5. Tamaño y espacio de los párrafos  (p) */
    .reveal p {
        font-size: 30px !important;    /* Ajusta este valor */
        margin-bottom: 15px !important; /* Espacio entre puntos */
        line-height: 1.3 !important;    /* Espacio entre líneas del mismo punto */
    }
     /* 6. Tamaño y espacio de la celda de codigos view */
   .reveal div pre {
        font-size: 20px !important;
    }
      /* 7. Tamaño y espacio de la celda de codigos  ESTO ES EL CÓDIGO QUE SE MUESTRA EN UNA CELDA MD
   .reveal div pre span {
        font-size: 32px !important;
    }*/
    /* Celdas de código edit*/
    .reveal .cm-line {
    font-size: 22px !important;
    }
       /* 8. esTILO H1, H2 y H3*/
   .reveal div h1{
        font-size: 48px !important;
        color: #4db6ac !important;
        text-transform: None;
    }
   .reveal div h2{
        font-size: 42px !important;
        text-transform: None;

    }
    .reveal div h3{
        /*font-size: 32px !important;*/
        text-transform: None !important;

    }
    
</style>
""")
# Out:
# <style>
#
#     /* 1. Tamaño y espacio de los ítems de lista (li) */
#     .reveal ul li, .reveal ol li {
#         font-size: 32px !important;    /* Ajusta este valor */
#         margin-bottom: 15px !important; /* Espacio entre puntos */
#         line-height: 1.3 !important;    /* Espacio entre líneas del mismo punto */
#     }
#
#     /* 2. Estilo de las sub-listas (listas dentro de listas) */
#     .reveal li > ul li, .reveal li > ol li {
#         font-size: 0.85em !important;   /* Un poco más pequeñas que las principales */
#         list-style-type: circle !important;
#     }
#
#     /* 3. Cambiar el color de las viñetas (bullets) */
#     .reveal ul li::marker {
#         color: #3498db !important;      /* Un azul sutil, cámbialo a tu gusto */
#         font-weight: bold;
#     }
#
#     /* 4. Ajustar el ancho del contenedor para que las listas no se corten */
#     .reveal .slides {
#         text-align: left !important;    /* Alinea el texto a la izquierda si prefieres */
#     }
#     /* 5. Tamaño y espacio de los párrafos  (p) */
#     .reveal p {
#         font-size: 30px !important;    /* Ajusta este valor */
#         margin-bottom: 15px !important; /* Espacio entre puntos */
#         line-height: 1.3 !important;    /* Espacio entre líneas del mismo punto */
#     }
#      /* 6. Tamaño y espacio de la celda de codigos view */
#    .reveal div pre {
#         font-size: 20px !important;
#     }
#       /* 7. Tamaño y espacio de la celda de codigos  ESTO ES EL CÓDIGO QUE SE MUESTRA EN UNA CELDA MD
#    .reveal div pre span {
#         font-size: 32px !important;
#     }*/
#     /* Celdas de código edit*/
#     .reveal .cm-line {
#     font-size: 22px !important;
#     }
#        /* 8. esTILO H1, H2 y H3*/
#    .reveal div h1{
#         font-size: 48px !important;
#         color: #4db6ac !important;
#         text-transform: None;
#     }
#    .reveal div h2{
#         font-size: 42px !important;
#         text-transform: None;
#
#     }
#     .reveal div h3{
#         /*font-size: 32px !important;*/
#         text-transform: None !important;
#
#     }
#
# </style>

# %% [markdown]
# # Lenguaje Python
# ## Cursada 2026
#
#
# ## Clase 2: listas, funciones y módulos

# %% [markdown]
# # En el video de cadenas planteamos el siguiente desafío:
#
# > Escribir un programa que ingrese 4 palabras desde el teclado e imprima aquellas que contienen la letra r.

# %% [markdown]
# ## Una posible solución:

# %%
for i in range(4):
    word = input("Ingresá una palabra: ")
    if "r" in word:
        print(f"{word} tiene una letra r")

# %% [markdown]
# - ¿Se acuerdan qué representa **f"{word} tiene una letra r"**?

# %% [markdown]
# # DESAFÍO 1
#
# > Vamos a modificar el código anterior para que se imprima la cadena "TIENE R" si la palabra contiene la letra r y sino, imprima "NO TIENE R".
#
# La solución casi immediata:

# %%
for i in range(4):
    word = input("Ingresá una palabra: ")
    if "r" in word:
        print("TIENE R")
    else:
        print("NO TIENE R")

# %% [markdown]
# **Hay otra forma de escribir estas expresiones condicionales.**

# %% [markdown]
# # Expresión condicional
#
# - La forma general es:
#
# ```python
# A if C else B
# ```
# - Devuelve A si se cumple la condición C, sino devuelve B.

# %%
number1 = int(input("Ingresá un número: "))
number2 = int(input("Ingresá un número: "))

number_max = number1 if number1 > number2 else number2 
number_max

# %% [markdown]
# ¿Por qué en no usamos el **print** en el código anterior?

# %% [markdown]
# # Escribimos otra solución al desafío

# %%
for i in range(4):
    word = input("Ingresá una palabra: ")
    print("TIENE R" if "r" in word else "NO TIENE R")

# %% [markdown]
# # Evaluación  del condicional
#
# **IMPORTANTE:** Python utiliza la <span style="color:#cd7815">**evaluación con circuito corto**</span> para evaluar las condiciones

# %%
number1 = 1
number2 = 0

if True or number1 / number2:
    print("No hay error!!!!???")

# %% [markdown]
# # DESAFÍO 2
#
# > Ingresar palabras desde el teclado hasta ingresar la palabra FIN. Imprimir aquellas que empiecen  y terminen con la misma letra.
# - ¿Qué estructura de control deberíamos utilizar para realizar esta iteración? ¿Podemos utilizar la sentencia **for**?

# %% [markdown]
# # Iteración condicional
#
# - Python tiene una <span style="color:#cd7815">sentencia **while**</span>. ¿Se acuerdan de este ejemplo?

# %%
## Adivina adivinador....
import random

random_number = random.randrange(5)
i_won = False
print("Tenés 2 intentos para adivinar un entre 0 y 4")
tries = 1

while tries < 3 and not i_won:
    entered_number = int(input("Ingresa tu número: "))
    if entered_number == random_number:
        print("Ganaste!")
        i_won = True
    else:
        print("Mmmm ... No.. ese número no es... Seguí intentando.")
        tries += 1
if not i_won:
    print("Perdiste :(")
    print(f"El número era: {random_number}")

# %% [markdown]
# # La sentencia while
#
# ```python
# while condition:
#     sentence
#     sentence
#
# ```
# **Nuestro desafío:**
# > Ingresar palabras desde el teclado hasta ingresar la palabra FIN. Imprimir aquellas que empiecen  y terminen con la misma letra.

# %%
# Solución al desafío

# %% [markdown]
# # DESAFÍO  3
# > Vamos a trabajar con las **películas argentinas candidatas al premio Oscar a mejor película extranjera**.
#
# Queremos saber:
# - ¿Cuál es la duración promedio, en minutos, de todas las películas?
# - ¿Cuántas películas duran más que el promedio, en minutos?

# %% [markdown]
# Datos según **ChatGPT**:
# ```
# Año de la ceremonia, Película, Resultado, Duración (minutos)
# 1975, La tregua, Nominada, 108
# 1985, Camila, Nominada, 105
# 1986, La historia oficial, Ganadora, 112
# 1999, Tango, no me dejes nunca, Nominada, 115
# 2002, El hijo de la novia, Nominada, 123
# 2010, El secreto de sus ojos, Ganadora, 129
# 2015, Relatos salvajes, Nominada, 122
# 2023, Argentina, 1985, Nominada, 140
# ```

# %% [markdown]
# ¿Cómo sería un pseudocódigo de esto?
# ```
# Ingresar la duración de las películas.
# Calcular el promedio.
# Calcular cuántas películas duran más que el promedio.
# ```
# ¿Cómo hacemos el **tercer** proceso? ¿Tenemos que ingresar las duraciones nuevamente?

# %% [markdown]
# Obviamente no. **Necesitamos tipos de datos que nos permitan guardar muchos valores**.

# %% [markdown]
# # Listas
#
#
# > <span style="color:#cd7815">Una **lista** es una colección ordenada de elementos.</span>

# %%
movies_duration = [108, 105, 112, 115, 123, 129, 122, 140]

type(movies_duration)

# %% [markdown]
# > Las listas son estructuras <span style="color:#cd7815">heterogéneas</span>, es decir que **pueden contener cualquier tipo de datos**, inclusive otras listas.

# %%
my_list = [1, "dos", [3, "cuatro"], True]
my_list

# %% [markdown]
#  ## ¿Se acuerdan de este método de <span style="color:#cd7815">**str**</span>?

# %%
my_list = "Somos campeones del  mundo!!!".split()
my_list

# %% [markdown]
# <span style="color:#cd7815">El **método split** retorna una **lista** </span>con los elementos de la cadena de caracteres.

# %% [markdown]
# ## Operaciones básicas

# %% [markdown]
# ¿Cuántos elementos tiene la lista?

# %%
len(my_list)

# %% [markdown]
# ## ¿Cómo agrego un elemento?
#
# Una forma:

# %%
my_list.append("NUEVO")
my_list

# %% [markdown]
# ¿Dónde se agregó el elemento nuevo?
# - **CONSIGNA:** <span style="color:#cd7815">buscar otras formas de agregar elementos a una lista.</span>

# %% [markdown]
# ## ¿Cómo elimino un elemento?
#
# Una forma:

# %%
my_list.pop(1)
my_list

# %% [markdown]
# ¿Qué elemento eliminamos?
# - **CONSIGNA:** <span style="color:#cd7815">buscar otras formas de eliminar elementos de una lista.</span>

# %% [markdown]
# ## Accediendo a los elementos de una lista
#
# - Se accede a través de **un índice** que indica la posición del elemento dentro de la lista **encerrado entre corchetes** [].
# - **IMPORTANTE:** al igual que las cadenas los índices comienzan en 0.

# %%
my_list = [ 17, "hola", [1, "dos"], 5.5, True] 
print(my_list[0])
print(my_list[2][1] )
print(my_list[-3])

# %% [markdown]
# **Las listas son datos MUTABLES.** ¿Qué quiere decir esto?

# %%
my_list

# %%
my_list[0] = ["El Dibu", 23]
my_list

# %% [markdown]
# # Asignación de listas
# Observemos el siguiente ejemplo:

# %%
rock = ["Riff", "La Renga", "La Torre"]
blues = ["La Mississippi", "Memphis"]
music = rock
rock[0] = "Rata Blanca"
print(music)

# %% [markdown]
# - Recordemos que las variables son **referencias a objetos**.

# %% [markdown]
# ¿Cuál es el problema?

# %% [markdown]
# - Cada objeto tiene un identificación.

# %%
#Recordemos que music = rock
print(id(music))
print(id(rock))
print(id(blues))

# %%
rock.append("Rata Blanca")
music

# %% [markdown]
# # Observemos este código

# %%
more_music = rock[:]
print(id(rock))
print(id(more_music))
print(id(music))

# %%
more_music.append("Hermetica")
rock

# %% [markdown]
# - **music = rock**: music y rock referencian al mismo objeto (misma zona de memoria).
# - **more_music = rock[:]**: more_music y rock referencian a dos objetos distintos (dos zonas de memoria distintas con el mismo contenido).
#
# **CONSIGNA:** <span style="color:#cd7815">buscar qué otras formas tenés en Python para trabajar una copia del objeto (no su referencia).</span>

# %%
# Otra forma
other_rock = rock.copy() 
id(other_rock)

# %% [markdown]
# # Recorriendo una lista
#
# - ¿Qué estructura de control les parece que podríamos usar?

# %%
for elem in my_list:
    print(elem)

# %% [markdown]
# ## Podríamos pensar en otra forma de recorrer la lista

# %%
list_len = len(my_list)
for i in range(list_len):
    print(my_list[i])

# %% [markdown]
# ¿Por qué no **range(list_len - 1)**?

# %% [markdown]
# # Operaciones con listas
#
# - Las listas se pueden concatenar (+) y repetir (*)

# %%
rock = ["Riff", "La Renga", "La Torre"]
blues =["La Mississippi", "Memphis"]

music = rock + blues
more_rock = rock * 3
more_rock

# %%
more_rock

# %% [markdown]
# # Algunas cosas para <span style="color:#cd7815">prestar atención</span>
#
# Analicemos el siguiente código:

# %%
my_list = [[1,2]] * 3 
my_list

# %%
my_list[0][1] = 'cambio'
my_list

# %% [markdown]
# - ¿Qué es lo que sucedió?
#     - El operador \* repite la **misma lista**, no genera una copia distinta; es el mismo objeto referenciado 3 veces.

# %% [markdown]
# # Probemos ahora:

# %%
my_list = [[1,2], [1, 2], [1, 2]]
my_list[0][1] = 'cambio'
my_list

# %% [markdown]
# # **CONSIGNA:** <span style="color:#cd7815">probar en casa </span> más operaciones sobre listas
#
# - Algunos métodos o funciones aplicables a listas: **extend()**, **index()**, **remove()**,	**count()**.
#
# - [+Info](https://docs.python.org/es/3/tutorial/datastructures.html) en la documentación oficial.
#
# - **IMPORTANTE:** ¿qué pueden decir de las siguientes asignaciones? ¿Se generan copias o referencias?

# %%
strange_list = [1, "dos", [3, "cuatro"]]
list1 = strange_list.copy() 
list2 = strange_list[:]

# %% [markdown]
# ¿Qué pasa con la lista original si ejecuto las siguientes instrucciones?

# %%
list1[1] = 0
list1[2][0] = 0

# %%
list2[1] = 10
list2[2][1] = 10

# %% [markdown]
# # Algo muy interesante: comprensión de listas (<span style="color:#cd7815">**list comprehension**</span>)
#
# Observemos el siguiente código: ¿qué elementos contiene la lista **codes**?

# %%
import string

letters = string.ascii_uppercase
codes = []
for letter in letters:
    codes.append(ord(letter))
print(codes)

# %% [markdown]
# Ahora usamos <span style="color:#cd7815">list comprehension</span>

# %%
letters = string.ascii_uppercase
codes = [ord(n) for n in letters]
print(codes)

# %% [markdown]
# ¿Y en este otro caso? ¿Cuáles son los elementos de **squares**?

# %%
squares = [num**2 for num in range(10) if num % 2 == 0]
squares

# %% [markdown]
# # DESAFÍO 4
#
# > Dada una lista de palabras, **usando list comprehension** generar otra lista con aquellos verbos en infinitivo.
#
# **IMPORTANTE:** solo vamos a comprobar que terminen en "ar", "er" o "ir".

# %%
#Una posible solución
words = ["c", "ir", "sol", "cantar","correr"]
verbs = [pal for pal in words if pal.endswith(("ar", "er", "ir"))]
verbs

# %% [markdown]
# # Retomamos el DESAFIO 3 de las películas
# Nuestro desafío era:
#
# > Queremos procesar las duraciones de las películas argentinas candidatas al premio Oscar a película extrajera.
#
# Queremos saber:
# - ¿Cuál fue la duración promedio, en minutos?
# - ¿Cuántas películas duran más que el promedio, en minutos?

# %% [markdown]
# La solución planteada era:
# ```
# Ingresar la duración de las películas.
# Calcular el promedio.
# Calcular cuántas películas duran más que el promedio.
# ```

# %% [markdown]
# ## Primer paso: generamos la lista con las duraciones

# %% [markdown]
# Si no sabemos cuántas películas vamos a procesar, vamos a suponer que ingresamos una duración igual a 0 para finalizar el ingreso de datos.
#
# ¿Cómo hacemos la iteración?

# %%
#Una posible solución
minutes = int(input("Ingresá la duración de una película (0 para finalizar): "))
movies_duration  = []
while minutes != 0:
    movies_duration.append(minutes)
    minutes = int(input("Ingresá la duración de una película (0 para finalizar): "))

movies_duration

# %% [markdown]
# Debemos partir de una lista vacía: []

# %% [markdown]
# ## Segundo paso: calculamos el promedio
#
# La solución clásica:

# %%
# Calculamos el promedio
total = 0
for minutes in movies_duration:
    total +=minutes

average = total / len (movies_duration)
average
# Out:
# 116.66666666666667

# %% [markdown]
# Más "Pythonic":

# %%
#Otra solución
average = sum(movies_duration) / len(movies_duration)
average
# Out:
# 116.66666666666667

# %% [markdown]
# **¡IMPORTANTE!** ¡Acá no estamos chequeando que la lista esté vacía!

# %% [markdown]
# ## Tercer paso: calculamos cuántas duran más que el promedio

# %%
#movies_duration = [108, 105, 112, 115, 123, 129, 122, 140]
#average = sum(movies_duration) / len(movies_duration)

max_average = [minutes for minutes in movies_duration if minutes > average]
print(f"{average = } - {max_average = }")
# Out:
# average = 116.66666666666667 - max_average = [200]

# %%
print(f"Hay {len(max_average)} película/s duran más que el promedio")
# Out:
# Hay 1 película/s duran más que el promedio

# %% [markdown]
# #  Funciones en Python: una forma de definir procesos o subprogramas
#
# Veamos un pseudocódigo de la solución del **DESAFÍO 3**:
# ```
# Ingresar la duración de las películas.
# Calcular el promedio.
# Calcular cuántas películas duran más que el promedio.
# ```
#
# Podríamos pensar en dividir en tres procesos:

# %% [markdown]
# - En Python, usamos <span style="color:#cd7815">**funciones**</span> para definir estos procesos.
# - Las funciones pueden recibir <span style="color:#cd7815">**parámetros**</span>.
# - Y también <span style="color:#cd7815">retornan **siempre** un valor</span>. Esto puede hacerse en forma implícita o explícita usando la sentencia **return**.

# %% [markdown]
# # Ya usamos funciones
#
#
# - float(), int(), str()
# - len(), ord()
# - input(), print()

# %% [markdown]
# En estos ejemplos, sólo <span style="color:#cd7815">**invocamos**</span> a las funciones ya definidas.

# %% [markdown]
# # Podemos definir nuestras propias funciones
#
# ```python
# 	def my_function(param1, param2):
# 		sentences
# 		return <expression>
# ```
# - **IMPORTANTE:** el cuerpo de la función debe estar **indentado**.

# %% [markdown]
# # Una posible función para el primer proceso del desafío:

# %%
def input_movies():
    """ This function returns a list with the duration in minutes of the movies """

    minutes = int(input("Ingresá la duración de una película  (0 para finalizar): "))
    movies_duration  = []
    while minutes != 0:
        movies_duration .append(minutes)
        minutes = int(input("Ingresá la duración de una película  (0 para finalizar): "))

    return movies_duration

# %%
movies = input_movies()
movies

# %% [markdown]
# - **¡IMPORTANTE!**
#     - <span style="color:#cd7815">Definición vs. invocación</span>.
#     - El **docstring**.

# %% [markdown]
# # El docstring
#
# - Es una secuencia de caracteres que describe la  función.
# - Se sugiere siempre utilizar  triples ".
# - **Son procesados por el intérprete.**

# %%
help(print)
#help(input_movies)

# %% [markdown]
# ## **CONSIGNA:** <span style="color:#cd7815">probar en casa</span>
#
# ¿Qué pasa si no incluyo la sentencia **return**? ¿Qué valor retorna la función?
#
# ```python
# def function_without_return():
#     var = 10
#     print(var)
#
# ```

# %%
## NO MSTRAR ESTO
def function_without_return():
    var = 10
    print(var)

print(function_without_return())

# %% [markdown]
# ## Ahora observemos este código que implementa una posible solución al segundo proceso

# %%
def average_calculation(movies_duration):
    """ This function calculates the average of the lengths of the movies received by parameter.
    movies_duration: is a list with the duration in minutes of the movies
    """
    
    len_movies = len(movies_duration)
    average = 0 if len_movies == 0 else sum(movies_duration) / len_movies
    return average

# %%
average_calculation(movies)

# %% [markdown]
# - A diferencia de la función anterior, ésta <span style="color:#cd7815">**tiene un parámetro**</span>.
# - ¿Hay distintas formas de pasar parámetros en Python? ¿Cómo podemos probar esto?

# %% [markdown]
# # **CONSIGNA:** <span style="color:#cd7815">probar en casa</span>
#
# - Definir la función restante para completar el desafío de las películas.
# - Escribir un programa que permita probar de qué forma se pasan los parámetros a las funciones en Python.
#
#     **PISTA:** probar con una función que reciba un entero y otra que reciba una lista.

# %% [markdown]
# # ¿Qué son los módulos en Python?

# %% [markdown]
# # <center> Un módulo es un archivo (con extensión .py)  que contiene sentencias y definiciones</center>
# <center>
# <img src="imagenes/modulos.png" alt="Actividad inicial" style="width:850px;"/>
# </center>

# %% [markdown]
# ## <center>¿Algo nuevo?</center>

# %% [markdown]
# #  Analicemos un ejemplo en el IDE
#
#
# - ¿Cuántos archivos forman mi programa?
# - ¿Cómo se relacionan?
# <center>
# <img src="imagenes/sentencia_import.png" alt="Actividad inicial" style="width:950px;"/>
# </center>

# %% [markdown]
# # La sentencia <span style="color:#cd7815">import</span>
#
# - Permite acceder a funciones y variables definidas en otro módulo.

# %%
import random

# %% [markdown]
# - Si el módulo contiene definiciones de funciones, sólo se importa estas definiciones, **no las ejecuta**.
# - Para ejecutar una función definida en otro módulo  **debo invocarla en forma explícita**.

# %%
random.randrange(10)

# %% [markdown]
# # Otra forma de importar
#
# ```python
# 	from my_module import my_function
# ```
# * Sólo se importa **my_function** de **my_module** (no el nombre del módulo).
#
# ```python
# 	from my_module import *
# ```
#
# * En este caso, importamos **todos los ítems** definidos en **my_module**.

# %% [markdown]
# * **Esta forma no está recomendada**: podrían existir conflictos de nombres. ¿Por qué?

# %%
from random import choice
numbers = [x ** 2 for x in range(1, 15, 2)]
choice(numbers)

# %%
choice = 10
choice

# %% [markdown]
# ## Veamos qué pasa cuando queremos importar un módulo que no existe:

# %%
import pp

# %% [markdown]
# ### ¿Dónde se busca los módulos?
#
# - Directorio actual + otros directorios definidos en la variable de ambiente PYTHONPATH

# %%
import sys
sys.path
# Out:
# ['/usr/lib/python312.zip',
#  '/usr/lib/python3.12',
#  '/usr/lib/python3.12/lib-dynload',
#  '',
#  '/home/clau/ownCloud/Materias/entornoPython/lib/python3.12/site-packages']

# %% [markdown]
# #  Los nombres de los módulos
#
# - Es posible acceder al  nombre de un módulo a través de **\_\_name__**

# %%
print(__name__)

# %% [markdown]
# ## ¿Cuándo un módulo se denomina  \_\_main__?

# %% [markdown]
# - Las instrucciones ejecutadas en el nivel de llamadas superior del intérprete, ya sea desde un script o interactivamente, se consideran parte del módulo llamado **\_\_main__**.

# %% [markdown]
# ```python
# #módulo utils
# print(f"El nombre de este módulo es {__name__}")
#
# if __name__ == "__main__":
#     one()
# ```

# %% [markdown]
# ¿Para qué creen que puede ser útil esto?

# %% [markdown]
# #  Agreguemos un menú al ejemplo anterior:
#
# <center>
# <img src="imagenes/name_main.png" alt="_main_" style="width:550px;"/>
# </center>

# %% [markdown]
# # Primero: ¿qué hace?

# %% [markdown]
# # Segundo:  ¿en qué casos se muestra el menú?

# %% [markdown]
# ¿Es posible utilizar las funciones sin invocar el menú?

# %%
if __name__ == "__main__":
    print(""" Elegí una opción:
    (1) one()
    (2( two()
    (3) three()
    """)
    option = int(input())
    match option:
        case 1: 
            one()
        case 2:
            two()
        case 3:
            three()

# %% [markdown]
# # Ahora:  ¿en qué casos se muestra el menú?

# %% [markdown]
# # **CONSIGNA:** <span style="color:#cd7815">probar en casa</span>
#
# Reimplementar el desafío de las películas usando funciones pensando que estas funciones se invocan desde el módulo donde están definidas o pueden invocarse desde desde otros módulos.
#
# - Los que quieran, pueden subir el código a su  repositorio en  GitHub y compartir el enlace a las cuentas **@clauBanchoff** y **@sofiamartin**.

# %% [markdown]
# # Seguimos la próxima  ...
